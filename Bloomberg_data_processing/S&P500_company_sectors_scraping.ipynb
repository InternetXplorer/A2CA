# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
wikiurl="https://en.wikipedia.org/wiki/List_of_S%26P_500_companies?fbclid=IwAR20RhvspvTHghzmyOOnfQYTJjhfWyt6nbdM9iJu31fYejkvWXhoGz6F97E"
table_class="wikitable sortable jquery-tablesorter"
response=requests.get(wikiurl)
print(response.status_code)
# Out:
# 200

# %%
# parse data from the html into a beautifulsoup object
soup = BeautifulSoup(response.text, 'html.parser')
indiatable=soup.find('table',{'class':"wikitable"})

# %%
df=pd.read_html(str(indiatable))
# convert list to dataframe
df=pd.DataFrame(df[0])
df
# Out:
#     Symbol            Security SEC filings             GICS Sector  \
# 0      MMM                  3M     reports             Industrials
# 1      AOS         A. O. Smith     reports             Industrials
# 2      ABT              Abbott     reports             Health Care
# 3     ABBV              AbbVie     reports             Health Care
# 4     ABMD             Abiomed     reports             Health Care
# ..     ...                 ...         ...                     ...
# 500    YUM         Yum! Brands     reports  Consumer Discretionary
# 501   ZBRA  Zebra Technologies     reports  Information Technology
# 502    ZBH       Zimmer Biomet     reports             Health Care
# 503   ZION       Zions Bancorp     reports              Financials
# 504    ZTS              Zoetis     reports             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota
# 1                     Building Products     Milwaukee, Wisconsin
# 2                 Health Care Equipment  North Chicago, Illinois
# 3                       Pharmaceuticals  North Chicago, Illinois
# 4                 Health Care Equipment   Danvers, Massachusetts
# ..                                  ...                      ...
# 500                         Restaurants     Louisville, Kentucky
# 501  Electronic Equipment & Instruments   Lincolnshire, Illinois
# 502               Health Care Equipment          Warsaw, Indiana
# 503                      Regional Banks     Salt Lake City, Utah
# 504                     Pharmaceuticals   Parsippany, New Jersey
#
#     Date first added      CIK      Founded
# 0         1976-08-09    66740         1902
# 1         2017-07-26    91142         1916
# 2         1964-03-31     1800         1888
# 3         2012-12-31  1551152  2013 (1888)
# 4         2018-05-31   815094         1981
# ..               ...      ...          ...
# 500       1997-10-06  1041061         1997
# 501       2019-12-23   877212         1969
# 502       2001-08-07  1136869         1927
# 503       2001-06-22   109380         1873
# 504       2013-06-21  1555280         1952
#
# [505 rows x 9 columns]

# %%
df=df.iloc[:,0:5]
df.drop("SEC filings",axis=1,inplace=True)

# %%
df.rename(columns={"Symbol":"Ticker"},inplace=True)
df.head()
# Out:
#   Ticker     Security  GICS Sector         GICS Sub-Industry
# 0    MMM           3M  Industrials  Industrial Conglomerates
# 1    AOS  A. O. Smith  Industrials         Building Products
# 2    ABT       Abbott  Health Care     Health Care Equipment
# 3   ABBV       AbbVie  Health Care           Pharmaceuticals
# 4   ABMD      Abiomed  Health Care     Health Care Equipment

# %%
df.to_csv('S&P500_company_sectors.csv', sep=",", index=False)

# %%
sp500=pd.read_csv("preprocessed_sp500_data_01-02-22.csv")
for i in range(len(sp500)):
    sp500.loc[i,"Ticker"] = sp500.loc[i,"Ticker"].split()[0] #extract ticker from long ticker code

sp500=df.merge(sp500,on='Ticker', how='left') #merge both dataframes on ticker column
sp500.head()
sp500.to_csv('preprocessed_sp500_final_data_01-02-22.csv', sep=",", index=False)
# Out:
#   Ticker     Security  GICS Sector         GICS Sub-Industry   CUR_MKT_CAP  \
# 0    MMM           3M  Industrials  Industrial Conglomerates  9.566949e+10
# 1    AOS  A. O. Smith  Industrials         Building Products  1.216317e+10
# 2    ABT       Abbott  Health Care     Health Care Equipment  2.253860e+11
# 3   ABBV       AbbVie  Health Care           Pharmaceuticals  2.420050e+11
# 4   ABMD      Abiomed  Health Care     Health Care Equipment  1.346134e+10
#
#    CURR_ENTP_VAL  NET_INCOME_FIRM  SALES_REV_TURN  NET_REV  GROSS_PROFIT  \
# 0   108530.49040      5809.107585       35355.000      NaN     16560.000
# 1    11750.76783       490.448034        3538.900      NaN      1310.900
# 2   234252.85710      4986.378019       43075.000      NaN     24538.000
# 3   310504.15690              NaN       45804.000      NaN     30417.000
# 4    12604.89137              NaN         847.522      NaN       685.615
#
#         EBIT     EBITDA   NET_DEBT  CURRENT_EV_TO_T12M_EBIT  \
# 0   7369.000   9420.000  12861.000                14.686868
# 1    609.500    687.400   -412.400                19.226403
# 2   8425.000   9013.000  12697.000                27.804493
# 3  11363.000  18026.000  78584.000                18.701690
# 4    229.557    257.754   -841.664                86.747219
#
#    CURRENT_EV_TO_T12M_EBITDA  PX_TO_SALES_RATIO  TRAIL_12M_NET_SALES  \
# 0                        NaN           2.718985            35355.000
# 1                  17.094512           3.459942             3538.900
# 2                  19.521071           5.261682            43075.000
# 3                  12.231797           4.394389            55169.000
# 4                  70.719042          13.766048              973.635
#
#    CURRENT_EV_TO_12M_SALES   PE_RATIO
# 0                 3.069735  16.427379
# 1                 3.320458  25.857856
# 2                 5.438256  29.555914
# 3                 5.628236  15.685116
# 4                12.946218  57.424660
