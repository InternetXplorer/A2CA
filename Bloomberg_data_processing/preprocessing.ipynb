# %% [markdown]
# ### Imports

# %%
import pandas as pd

# %% [markdown]
# ### Data loading

# %%
path = "original_data/"
filename = "russell_3k_data_14-03-22.csv"

data = pd.read_csv(path + filename, sep=";", decimal=",", na_values=['#N/A Field Not Applicable'])

# %%
data.head(2)
# Out:
#           Ticker                         Nom   SUB_IND_GICS     IND_GICS  \
# 0   AA UN Equity                  Alcoa Corp       Aluminum    Materials
# 1  INO UW Equity  Inovio Pharmaceuticals Inc  Biotechnology  Health Care
#
#      REGION_NAME   CUR_MKT_CAP  CURR_ENTP_VAL  NET_INCOME_FIRM  \
# 0  United States  1.369201e+10   15267.809120       521.702252
# 1  United States  6.880814e+08     319.789847              NaN
#
#    SALES_REV_TURN  NET_REV  ...  CURRENT_EV_TO_T12M_EBITDA  PX_TO_SALES_RATIO  \
# 0    12152.000000      NaN  ...                   9.071782           1.128767
# 1        1.774758      NaN  ...                        NaN         374.061876
#
#    TRAIL_12M_NET_SALES  CURRENT_EV_TO_12M_SALES   PE_RATIO  NUM_OF_EMPLOYEES  \
# 0         12152.000000                 1.256403  12.379874           12200.0
# 1             1.774758               180.187861        NaN             317.0
#
#    SUSTAIN_GROWTH_RT   PROF_MARGIN  Unnamed: 23  Datetime of data import
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3040 entries, 0 to 3039
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Ticker                     3040 non-null   object
#  1   Nom                        3040 non-null   object
#  2   SUB_IND_GICS               3037 non-null   object
#  3   IND_GICS                   3037 non-null   object
#  4   REGION_NAME                3040 non-null   object
#  5   CUR_MKT_CAP                3039 non-null   float64
#  6   CURR_ENTP_VAL              2804 non-null   float64
#  7   NET_INCOME_FIRM            1232 non-null   float64
#  8   SALES_REV_TURN             3010 non-null   float64
#  9   NET_REV                    334 non-null    float64
#  10  GROSS_PROFIT               2201 non-null   float64
#  11  EBIT                       2719 non-null   float64
#  12  EBITDA                     2688 non-null   float64
# ...

# %% [markdown]
# ### Dropping useless column & renaming

# %%
for index,row in data.iterrows():
    data.replace(row["Ticker"], row["Ticker"].split(" ")[0], inplace=True)

# %%
data = data.rename(columns={data.columns.values[0]:"Ticker"})

date_column = "Datetime of data import"
if(date_column in data.columns.values):
    data = data.drop(columns=["Datetime of data import"])

# %%
data.head(2)
# Out:
#   Ticker                         Nom   SUB_IND_GICS     IND_GICS  \
# 0     AA                  Alcoa Corp       Aluminum    Materials
# 1    INO  Inovio Pharmaceuticals Inc  Biotechnology  Health Care
#
#      REGION_NAME   CUR_MKT_CAP  CURR_ENTP_VAL  NET_INCOME_FIRM  \
# 0  United States  1.369201e+10   15267.809120       521.702252
# 1  United States  6.880814e+08     319.789847              NaN
#
#    SALES_REV_TURN  NET_REV  ...  CURRENT_EV_TO_T12M_EBIT  \
# 0    12152.000000      NaN  ...                15.982783
# 1        1.774758      NaN  ...                      NaN
#
#    CURRENT_EV_TO_T12M_EBITDA  PX_TO_SALES_RATIO  TRAIL_12M_NET_SALES  \
# 0                   9.071782           1.128767         12152.000000
# 1                        NaN         374.061876             1.774758
#
#    CURRENT_EV_TO_12M_SALES   PE_RATIO  NUM_OF_EMPLOYEES  SUSTAIN_GROWTH_RT  \
# 0                 1.256403  12.379874           12200.0                NaN
# ...

# %% [markdown]
# ### Show some statistics

# %%
print("Number of missing values per column :\n")
print(data.isnull().sum())
# Out:
# Number of missing values per column :
#
# Ticker                          0
# Nom                             0
# SUB_IND_GICS                    3
# IND_GICS                        3
# REGION_NAME                     0
# CUR_MKT_CAP                     1
# CURR_ENTP_VAL                 236
# NET_INCOME_FIRM              1808
# SALES_REV_TURN                 30
# NET_REV                      2706
# GROSS_PROFIT                  839
# EBIT                          321
# EBITDA                        352
# NET_DEBT                       12
# CURRENT_EV_TO_T12M_EBIT      1175
# CURRENT_EV_TO_T12M_EBITDA    1083
# PX_TO_SALES_RATIO             219
# TRAIL_12M_NET_SALES            74
# CURRENT_EV_TO_12M_SALES       486
# PE_RATIO                     1003
# NUM_OF_EMPLOYEES              353
# SUSTAIN_GROWTH_RT            1217
# PROF_MARGIN                   157
# Unnamed: 23                  3040
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3040 entries, 0 to 3039
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Ticker                     3040 non-null   object
#  1   Nom                        3040 non-null   object
#  2   SUB_IND_GICS               3037 non-null   object
#  3   IND_GICS                   3037 non-null   object
#  4   REGION_NAME                3040 non-null   object
#  5   CUR_MKT_CAP                3039 non-null   float64
#  6   CURR_ENTP_VAL              2804 non-null   float64
#  7   NET_INCOME_FIRM            1232 non-null   float64
#  8   SALES_REV_TURN             3010 non-null   float64
#  9   NET_REV                    334 non-null    float64
#  10  GROSS_PROFIT               2201 non-null   float64
#  11  EBIT                       2719 non-null   float64
#  12  EBITDA                     2688 non-null   float64
# ...

# %%
data.describe()
# Out:
#         CUR_MKT_CAP  CURR_ENTP_VAL  NET_INCOME_FIRM  SALES_REV_TURN  \
# count  3.039000e+03   2.804000e+03      1232.000000     3010.000000
# mean   1.563339e+10   1.865190e+04      1566.811250     6339.024876
# std    8.764096e+10   8.944415e+04      5988.164136    25363.381914
# min    1.947602e+07  -2.034655e+03     -2780.542857      -72.927000
# 25%    6.669903e+08   7.884168e+02        81.375749      244.745500
# 50%    2.160236e+09   3.093702e+03       280.374724      985.550500
# 75%    7.069112e+09   1.064498e+04      1018.151529     3501.181250
# max    2.476560e+12   2.396759e+06     96973.155200   572754.000000
#
#              NET_REV   GROSS_PROFIT           EBIT         EBITDA  \
# count     334.000000    2201.000000    2719.000000    2688.000000
# mean     3326.962406    2573.371582     888.936692    1324.263090
# std     11712.477636   10398.686834    4731.626260    5955.066598
# min       -61.637000    -960.051000   -7090.000000   -4654.000000
# ...

# %% [markdown]
# ### Save to CSV file

# %%
new_filename = "preprocessed_" + filename
data.to_csv(new_filename, sep=",", index=False)
